# %% [raw]
# ---
# title: "A Jupyter Notebook with my incredible R code"
# author: "José R. Ferrer-Paris"
# date: "8 Dec 2023"
# affiliation:
#  - "Centre for Ecosystem Science"
#  - "UNSW codeRs"
# format: html
# jupyter: R
# ---

# %% [markdown]
# ## <a title="Jupyter project logo" href="https://jupyter-notebook.readthedocs.io/"><img height="50" alt="Jupyter logo" src="https://jupyter-notebook.readthedocs.io/en/stable/_static/logo-rectangle.svg"></a>
#
# [Project Jupyter](https://jupyter.org/) develops open-source software, open standards, and services for interactive computing across multiple programming languages.
#
# Jupyter supports execution environments (called "kernels") in several dozen languages, including Julia, R, Haskell, Ruby, and Python.

# %% [markdown]
# ## <a title="quarto logo" href="https://quarto.org"><img height="50" alt="quarto logo" src="https://quarto.org/quarto.png"></a>
#
# [Quarto](https://quarto.org) is an open-source scientific and technical publishing system. It enables you to weave together content and executable code into a finished document.
#
# Quarto can use Jupyter notebooks to create dynamic content or reproducible documents.
#
# When you render a Jupyter notebook with Quarto, the contents of the notebook (code, markdown, and outputs) are converted to plain markdown and then processed by Pandoc, which creates the finished format.
#
# ![Quarto workflow with jupyter notebook](https://quarto.org/docs/get-started/hello/images/ipynb-how-it-works.png)

# %% [markdown]
# ## This is my great R code

# %% [markdown]
# ### Load the libraries
# We need `magick` to read the images, `ggplot2` for plotting and and `cowplot` for arranging the grid of plots and images.

# %%
library(ggplot2)
library(cowplot)
library(magick)
# Out:
# Linking to ImageMagick 6.9.12.3
# Enabled features: cairo, fontconfig, freetype, heic, lcms, pango, raw, rsvg, webp
# Disabled features: fftw, ghostscript, x11

# %% [markdown]
# ### Locate the images
# We use the functions from package `here` to establish our project root, and then use the relative paths to the images

# %%
here::i_am("presentation/showcase-your-research.qmd")
yes_img <- here::here("images/yes.png")
no_img <- here::here("images/no.png")
# Out:
# here() starts at /Users/z3529065/proyectos/codeRs/showcase-your-research

# %% [markdown]
# We use functions from `cowplot` to set up drawing layers in top of blank `ggplot2` canvas. This requires the `magick` package to read and manipulate the images internally.

# %%
yes_plot <- ggdraw() + draw_image(yes_img, scale = 1)
no_plot <- ggdraw() + draw_image(no_img, scale = 1)

# %% [markdown]
# ### This is a bad plot
# Sometimes we do silly mistakes when we are learning to use a package. This is one example:

# %%
#| label: badplot
#| fig-cap: This is not the way to use the colour aesthetic
(bad_plot <- 
  ggplot(mpg, aes(x = displ, y = hwy, colour = "blue")) +
  geom_point())
# Out:
# plot without title

# %% [markdown]
# ### This is a good plot
# Adding layers of `ggplot2` functions allow us to customise plots and make them ready for publication.

# %%
#| label: goodplot
#| fig-cap: This plot is so nice!
(good_plot <- 
  ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point(colour = "blue") +
  geom_smooth(colour = "red") + 
  theme_half_open(12) +
  labs(x = "Engine power (litres displ.)",
       y = "Fuel Efficiency (miles/gallon)"))
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# ### Conclusion

# %%
#| label: meme
#| fig-cap: This grid shows the progress from novice to expert in `ggplot2`
plot_grid(no_plot, bad_plot,
          yes_plot, good_plot)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# ## Render this document
#
# Open a terminal in the same directory as this file and then type:
#
# - `quarto render Example.ipynb --to html` for html output
# - `quarto render Example.ipynb --to docx` for docx output
